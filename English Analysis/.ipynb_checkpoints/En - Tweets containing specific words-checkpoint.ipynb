# %%
import json, os, glob
import pandas as pd
import feather
from collections import Counter
from pathlib import Path

rows = []
links = []
#num = Path('2020-03-19.json').stat().st_size
count=0

json_dir = 'en'
# Uses the json_dir variable to navigate to the dataset directory and 'get' all json files
json_pattern = os.path.join(json_dir, '*.json')

# Uses Glob with the json pattern variable to place all the json files and their directories in a list
file_list = glob.glob(json_pattern)

# directory to save data to
save_dir = "./TweetsContainingPutinKremlinOligarchRussia.ftr"

# Opens the JSON file
for file in file_list:
    with open(file, 'r') as f:
        for line in f:
            if count > 10000:
                break
            count = 0
            data = json.loads(line)
            
            # If there is a long version of the tweet
            if "extended_tweet" in data:
                data_list = data["extended_tweet"]["full_text"].split()
                for i in data_list:
                    # The strings in the following conditional can be substituted for other search params
                    if i.lower() == "putin" or i.lower() == "kremlin" or i.lower() == "oligarch" or i.lower() == "russia":
                        count+=1
            # If there is only a short version of the tweet
            else:
                data_list = data["text"].split()
                for i in data_list:
                    # The strings in the following conditional can be substituted for other search params
                    if i.lower() == "putin" or i.lower() == "kremlin" or i.lower() == "oligarch" or i.lower() == "russia":
                        count+=1

            if count == 1:
                #username
                user_id = data["user"]["screen_name"]
                #location
                user_location = data["user"]["location"]
                #Tweet ID
                tweet_id = data["id_str"]
                #Hashtags
                hashtags = data["entities"]["hashtags"]
                #tweet text
                if "extended_tweet" in data:
                    text = data["extended_tweet"]["full_text"]
                else:
                    text = data["text"]
                rows.append((user_id, user_location, tweet_id, hashtags, text))
        
pd.options.display.max_colwidth = 500
datas = pd.DataFrame(rows, columns=["user_id", "user_location", "tweet_id", "hashtags", "text"])
datas.to_feather(save_dir)
display(datas)
# Out:
#               user_id      user_location             tweet_id  \
# 0       MickeyMccowen               None  1242964470726569984
# 1           sundanz63       Florida, USA  1242964380045770754
# 2         Alllwftopic         Everywhere  1242964299720486912
# 3       kielar_robert               None  1242964158150295552
# 4            Boobaloo  San Francisco, CA  1242963909872500737
# ...               ...                ...                  ...
# 14419       MsPacNWer      United States  1245139322015109122
# 14420  donald_j_putin       New York, NY  1245139165047635970
# 14421    PCUnitedPage      United States  1245139075834626049
# 14422       quarkifus         California  1245139012852957184
# 14423   Moscow_a_Lago               None  1245138915419230208
#
#                                                         hashtags  \
# 0                                                             []
# 1                                                             []
# 2                                                             []
# 3                                                             []
# 4                                                             []
# ...                                                          ...
# 14419  [{'indices': [17, 40], 'text': 'ThingsKremlinTrollsSay'}]
# 14420                                                         []
# 14421                                                         []
# 14422             [{'indices': [50, 62], 'text': 'coronavirus'}]
# 14423                                                         []
#
#                                                                                                                                                                                                                                                                                                                                                     text
# 0                                           @MarshaBlackburn I wonder if you’d feel the same if it were Russia that had suppressed COVID-19 information &amp; destroyed tests. Why are you so anti China? Why aren’t you so Anti-Russia—they interfered in our elections? Why did you block 3 Prevention of Foreign Interference in our Elections bills?
# 1                                                                                                                                                                                                                                        RT @JayRouseDC: @ericgarland Not a conspiracy theorist but 658 cases in Russia and 657 cases in India seems odd
# 2                                                                                                                                                                 @foward_thinker @harpreetkdha @DynastyClaire Goes to show you that all your accounts need to be reported and suspended for tweeting out Russian propaganda by a Russian Putin groupie.
# 3                                                                                          @Kyruer Russia And China use perfectly the situation and make good things, like helping the Italy, but with the idea to weakened the european society, and always with connection of fake news, like that the Poland stops russians IL-76 with aid for Italy.
# 4                                                                                                                                                                                                        @AngelaLencewicz @ali @realDonaldTrump “Junkie” is accurate, 4 years of Russia conspiracy not enough, immune to facts reason, diagnose yourself
# ...                                                                                                                                                                                                                                                                                                                                                  ...
# 14419                                                                                                                                               @Victori23058592 #ThingsKremlinTrollsSay  Indeed, *Victori*, you evidence as a fake Kremlin troll acct &amp; provided NOTHING of intellectual value.  You've earned a BLOCK. https://t.co/TpfiSO6rit
# 14420  @Robertamnesia @FakaktaSouth @PixMichelle @MajorSnowflake I didn't know them in their "black lives matter" personae; I can tell you that I saw them early on Russia Today programs (am a fan; obvious reasons... hate taste of novachok and polonium!), so they were part of the integrated right-wing propaganda machine. Left doesn't pay well.
# 14421                                                                                                                                                                                                                                                @TeaPainUSA While Trump accepts Russian medical supplies, Putin is gearing up his propaganda virus.
# 14422                                                                                                                                                                                                        RT @MTsitsikashvili: Panic and fear resulted from #coronavirus pandemic have provided fertile ground for the disinformation and Russia has…
# 14423                                                                                                                                                                                                       RT @olgaNYC1211: This is absolutely disgusting and Putin will use this as propaganda just like he does w Italy with media showing Russian t…
#
# [14424 rows x 5 columns]

# %%
import re
import pandas as pd
import feather
import matplotlib.pyplot as plt

# adjustable file in ftr format
save_dir = "./TweetsContainingPutinKremlinOligarchRussia.ftr"

# reads contents of save_dir.ftr
read_ftr = pd.read_feather(save_dir, columns=None, use_threads=True);

# adjustable vocabulary list.
# only works if the words do not contain whitespace.
vocab = ["i", "we", "you", "they", "us"]

# series to list adapter
# Places all tweet text in a list, seperated by word.
s = (" ".join(read_ftr["text"]).split())

# creates a dictionary object where k=vocab[x] and v=counter
wordcount = dict((x,0) for x in vocab)

# for each w in text, if w is in the dictionary object, increase the respective counter.
for i in s:
    for w in re.findall(r"\w+", i):
        if w in wordcount:
            wordcount[w] += 1
            
# prints results to console.
print(wordcount)
plt.bar(range(len(wordcount)), list(wordcount.values()), align='center')
plt.xticks(range(len(wordcount)), list(wordcount.keys()))
plt.savefig('en-03-2020-freq-of-pronouns.png')
# Out:
# {'i': 259, 'we': 437, 'you': 1770, 'they': 739, 'us': 219}

# %%
import re
import pandas as pd
import feather
from collections import Counter
import matplotlib.pyplot as plt

# adjustable file in ftr format
save_dir = "./TweetsContainingPutinKremlinOligarchRussia.ftr"

# reads contents of save_dir.ftr
read_ftr = pd.read_feather(save_dir, columns=None, use_threads=True);

# finds 100 most common words
Counter(" ".join(read_ftr["text"]).split()).most_common(100)
# Out:
# [('the', 10771),
#  ('Russia', 10388),
#  ('and', 9966),
#  ('to', 9248),
#  ('RT', 8552),
#  ('China', 4825),
#  ('a', 4403),
#  ('is', 4169),
#  ('disinformation', 3852),
#  ('of', 3543),
#  ('in', 3334),
#  ('for', 3294),
#  ('that', 3154),
#  ('on', 3150),
#  ('coronavirus', 3049),
#  ('propaganda', 2886),
#  ('Putin', 2426),
#  ('have', 2364),
#  ('are', 2210),
#  ('about', 2032),
#  ('As', 1900),
#  ('The', 1693),
#  ('campaigns', 1648),
#  ('wage', 1586),
#  ('seized', 1580),
#  ('Disinformation', 1500),
#  ('you', 1457),
#  ('U.S.', 1399),
#  ('Virus', 1393),
#  ('as', 1384),
#  ('See', 1373),
#  ('and…', 1366),
#  ('Spreads,', 1356),
#  ('Openings', 1356),
#  ('from', 1348),
#  ('it', 1336),
#  ('with', 1301),
#  ('seek', 1280),
#  ('undermine', 1224),
#  ('outbreak', 1190),
#  ('@nytimes:', 1119),
#  ('this', 1097),
#  ('Kremlin', 1087),
#  ('I', 1086),
#  ('Trump', 1082),
#  ('by', 1038),
#  ('&amp;', 1035),
#  ('@JohnCornyn:', 1017),
#  ('https://t.co/48PzpBWNrH', 1004),
#  ('who', 991),
#  ('conspiracy', 988),
#  ('their', 987),
#  ('Russian', 946),
#  ('has', 946),
#  ('fake', 884),
#  ('not', 842),
#  ('spread', 842),
#  ('media', 837),
#  ('was', 835),
#  ('news', 806),
#  ('like', 757),
#  ('be', 747),
#  ('-', 685),
#  ('di', 650),
#  ('they', 630),
#  ('he', 612),
#  ('what', 609),
#  ('at', 600),
#  ('or', 582),
#  ('all', 576),
#  ('same', 574),
#  ('This', 574),
#  ('but', 572),
#  ('just', 551),
#  ('sow', 544),
#  ('use', 540),
#  ('your', 537),
#  ('another', 507),
#  ('Coronavirus', 504),
#  ('will', 501),
#  ('his', 495),
#  ('US', 488),
#  ('more', 486),
#  ('And', 464),
#  ('opportunity', 457),
#  ('You', 456),
#  ('how', 448),
#  ('@washingtonpost:', 445),
#  ('gives', 439),
#  ('do', 435),
#  ('out', 417),
#  ('up', 414),
#  ('people', 413),
#  ('China,', 412),
#  ('doubts', 411),
#  ('than', 409),
#  ('claim', 408),
#  ('propaganda.', 401),
#  ('other', 396),
#  ('Europe', 392)]

# %% [markdown]
# [ ftr to text ]

# %%
f = open("PutinKremlinOligarchRussiaText.txt", "w+", encoding="utf8")

# adjustable file in ftr format
save_dir = "./allEnglishTweets.txt"

# reads contents of save_dir.ftr
read_ftr = pd.read_feather(save_dir, columns=None, use_threads=True);

s = (" ".join(read_ftr["text"]).split())

for i in s:
    f.write(i)
    f.write("\n")

f.close()
