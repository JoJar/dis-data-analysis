# %%
import json, os, glob
import pandas as pd
import feather
from collections import Counter
from pathlib import Path

rows = []
links = []
count=0

json_dir = 'russianDataSets/ru/'
# Uses the json_dir variable to navigate to the dataset directory and 'get' all json files
json_pattern = os.path.join(json_dir, '*.json')

# Uses Glob with the json pattern variable to place all the json files and their directories in a list
file_list = glob.glob(json_pattern)

# directory to save data to
save_dir = "./russianTweetsContainingPropaganda.ftr"

# Opens the JSON file
for file in file_list:
    with open(file, 'r') as f:
        for line in f:
            if count > 10000:
                break
            count = 0
            data = json.loads(line)
            
            # If there is a long version of the tweet
            if "extended_tweet" in data:
                data_list = data["extended_tweet"]["full_text"].split()
                for i in data_list:
                    # The strings in the following conditional can be substituted for other search params
                    if i.lower() == "пропаганда":
                        count+=1
            # If there is only a short version of the tweet
            else:
                data_list = data["text"].split()
                for i in data_list:
                    # The strings in the following conditional can be substituted for other search params
                    if i.lower() == "пропаганда":
                        count+=1

            if count >= 1:
                #username
                user_id = data["user"]["screen_name"]
                #location
                user_location = data["user"]["location"]
                #Tweet ID
                tweet_id = data["id_str"]
                #Hashtags
                hashtags = data["entities"]["hashtags"]
                #tweet text
                if "extended_tweet" in data:
                    text = data["extended_tweet"]["full_text"]
                else:
                    text = data["text"]
                rows.append((user_id, user_location, tweet_id, hashtags, text))
        
pd.options.display.max_colwidth = 500
datas = pd.DataFrame(rows, columns=["user_id", "user_location", "tweet_id", "hashtags", "text"])
datas.to_feather(save_dir)
display(datas)
# Out:
#                user_id          user_location             tweet_id  \
# 0           ColdAbbess                Андван.  1234262876782759938
# 1           wurst_olga                   None  1234262222924402688
# 2         Oleg71407575                   None  1234259551823826944
# 3            alexxbezz  Warszawa, Mazowieckie  1234259256309899264
# 4               777hjr                   None  1234254504368930816
# ...                ...                    ...                  ...
# 43571          Deryban                Україна  1277788078527131648
# 43572        voffchara                   None  1277784729660489728
# 43573          Yagor68        Сибирская тайга  1277771082142023680
# 43574  dHGhg0e1G6fomMk                   None  1277767302138691585
# 43575         zema6767                   None  1277763495237484546
#
#                                                                                           hashtags  \
# 0                                                                                               []
# 1      [{'indices': [21, 31], 'text': 'ДляТюрьмы'}, {'indices': [32, 45], 'text': 'ДляЛюстрации'}]
# 2                                                                                               []
# 3                                                                                               []
# 4      [{'indices': [21, 31], 'text': 'ДляТюрьмы'}, {'indices': [32, 45], 'text': 'ДляЛюстрации'}]
# ...                                                                                            ...
# 43571                                                                                           []
# 43572                                                                                           []
# 43573                                                                                           []
# 43574                                                                                           []
# 43575                                                                                           []
#
#                                                                                                                                                                                                                                                                                                                             text
# 0                         @Shining_Stri Задача непростая. Тут можно силовыми методами. Неверных в бездну к хуям, а остальные пусть присекают в верности. Опять же, при этом лютая, но обоснованная и хорошо продуманная пропаганда должна быть. Нужно показать плюсы Тёмной стороны, все плюшки и вундкрвафли в отношении ситхов
# 1                                                                                                                                                                                               RT @RabinovichSlava: #ДляТюрьмы #ДляЛюстрации\n\nПРОПАГАНДА УБИВАЕТ\n\nТекст для видео в следующем твите https://t.co/mp4N2zuBvd
# 2                                                                                                                                                                                RT @Search_Veritas: Как в воду глядел))\nВчера оставил этот комментарий.\nhttps://t.co/n0iDDIsl6D\nСегодня вся пропаганда показывает этого чел…
# 3                                                                                                                                                                                    RT @CommanderAntiZe: В следующий раз, когда пропаганда будет рассказывать про Харьков и Одессу, как "русские города", покажите этот видос.…
# 4                                                                                                                                                                                               RT @RabinovichSlava: #ДляТюрьмы #ДляЛюстрации\n\nПРОПАГАНДА УБИВАЕТ\n\nТекст для видео в следующем твите https://t.co/mp4N2zuBvd
# ...                                                                                                                                                                                                                                                                                                                          ...
# 43571                                                                                                                                                                               RT @GlennARathn: Тепер можна впевнено стверджувати, що не існує "акадємічєской історічєской ноукі", замість неї московська пропаганда серед…
# 43572  @BAZZTstBmc9k2GJ @tsylechka @pani_walewska Он такой же и расист как антисемит (очень хреновый). Вы уж там договоритесь между собой, какие методички юзать ;)\n\nПоразительно, конечно, как телевизор и левая пропаганда делает людей овощами с полностью выключенным критическим мышлением не только в России но и в США.
# 43573                                                                                                                                          Что все молчат по поводу смены логотипов автопромом? Это  же пропаганда ЛГБТ Твиттером на территории России!!! Алле, народ и следственный комитет РФ \n тоже. Как жалоба пишется?
# 43574                                                                                                                                                                               RT @ypo6opoc: Поэтому вся эта эпидерсия с крупными компаниями, с кока-колой, BMW и прочими, - это сраная пропаганда и предательство. Никогд…
# 43575                                                                                                                                                                                                                 RT @varjag2007su: Пропаганда ЛГБТ на Украине велась при поддержке руководства УГКЦ https://t.co/PGFNXMxCYR
#
# [43576 rows x 5 columns]

# %%
import re
import pandas as pd
import feather
from collections import Counter

# adjustable file in ftr format
save_dir = "./russianTweetsContainingPropaganda.ftr"

# reads contents of save_dir.ftr
read_ftr = pd.read_feather(save_dir, columns=None, use_threads=True);

# finds 100 most common words
Counter(" ".join(read_ftr["text"]).split()).most_common(100)
# Out:
# [('пропаганда', 34965),
#  ('RT', 23859),
#  ('в', 22979),
#  ('и', 21472),
#  ('не', 14965),
#  ('на', 12575),
#  ('что', 10560),
#  ('Пропаганда', 8308),
#  ('-', 6658),
#  ('это', 6436),
#  ('как', 6169),
#  ('с', 5440),
#  ('а', 4235),
#  ('за', 4089),
#  ('о', 3974),
#  ('@prof_preobr:', 3905),
#  ('у', 3701),
#  ('к', 2895),
#  ('по', 2696),
#  ('то', 2602),
#  ('А', 2446),
#  ('уже', 2375),
#  ('все', 2049),
#  ('И', 2033),
#  ('про', 2009),
#  ('из', 1969),
#  ('нас', 1881),
#  ('от', 1863),
#  ('так', 1826),
#  ('же', 1818),
#  ('Как', 1781),
#  ('Это', 1734),
#  ('В', 1670),
#  ('я', 1666),
#  ('государственная', 1629),
#  ('но', 1553),
#  ('для', 1545),
#  ('только', 1538),
#  ('да', 1479),
#  ('есть', 1424),
#  ('они', 1415),
#  ('российская', 1409),
#  ('их', 1395),
#  ('і', 1381),
#  ('кто', 1331),
#  ('будет', 1312),
#  ('день', 1275),
#  ('—', 1204),
#  ('его', 1203),
#  ('Я', 1188),
#  ('Но', 1172),
#  ('просто', 1170),
#  ('этом', 1142),
#  ('лет', 1141),
#  ('или', 1131),
#  ('когда', 1114),
#  ('США', 1094),
#  ('се', 1087),
#  ('та', 1084),
#  ('@A_Vit_:', 1083),
#  ('со', 1070),
#  ('бы', 1052),
#  ('до', 1024),
#  ('то,', 1009),
#  ('всех', 1008),
#  ('даже', 1006),
#  ('против', 993),
#  ('во', 974),
#  ('вот', 972),
#  ('ПРОПАГАНДА', 967),
#  ('РФ', 966),
#  ('ее', 959),
#  (',', 941),
#  ('Це', 936),
#  ('он', 931),
#  ('она', 930),
#  ('Путин', 930),
#  ('этой', 929),
#  ('вы', 919),
#  ('том', 918),
#  ('Италию', 907),
#  ('очень', 905),
#  ('если', 900),
#  ('российские', 889),
#  ('из-за', 884),
#  ('том,', 871),
#  ('там', 862),
#  ('всё', 853),
#  ('через', 843),
#  ('Не', 833),
#  ('России', 824),
#  ('в…', 811),
#  ('где', 802),
#  ('работает', 801),
#  ('чтобы', 800),
#  ('вся', 798),
#  ('меня', 779),
#  ('сами', 778),
#  ('жить', 773),
#  ('её', 771)]
