# %%
import json, os, glob
from tqdm import tqdm_notebook as tqdm
import pandas as pd
from collections import Counter
from pathlib import Path

rows = []
links = []
#num = Path('2020-03-19.json').stat().st_size
count=0

json_dir = 'russianDataSets/ru'
# Uses the json_dir variable to navigate to the dataset directory and 'get' all json files
json_pattern = os.path.join(json_dir, '*.json')

# Uses Glob with the json pattern variable to place all the json files and their directories in a list
file_list = glob.glob(json_pattern)

# directory to save data to
save_dir = "allLinks.2020.RussianTweets.ftr"

# Opens the JSON file
for file in file_list:
    with open(file, 'r') as f:
        for line in f:
            if count > 10000:
                break
            count = 0
            data = json.loads(line)

            if len(data["entities"]["urls"]) > 0:
                count+=1

            if count == 1:
                #username
                user_id = data["user"]["screen_name"]
                #location
                user_location = data["user"]["location"]
                #Tweet ID
                tweet_id = data["id_str"]
                #Hashtags
                hashtags = data["entities"]["hashtags"]
                #tweet text
                urls = data["entities"]["urls"]
                rows.append((urls[0].get("expanded_url")))

pd.options.display.max_colwidth = 500
datas = pd.DataFrame(rows, columns=["urls"])
datas.to_feather(save_dir)
display(datas)
# Out:
#                                                                                                                                                    urls
# 0                                                                                                  https://twitter.com/i/web/status/1234266183731421184
# 1                                                                                                  https://twitter.com/i/web/status/1234262876782759938
# 2                                                                                                  https://twitter.com/i/web/status/1234261668558827521
# 3                                                                                                                              https://goo.gl/fb/ouHgYf
# 4                                                                                         https://twitter.com/Search_Veritas/status/1233773290583404544
# ...                                                                                                                                                 ...
# 86175                                                                                                                            https://bit.ly/2Vtm35I
# 86176                                                                                              https://twitter.com/i/web/status/1277756878077022208
# 86177                                                                                              https://twitter.com/i/web/status/1277754946784563200
# 86178                                                                                                                            http://jenke.rs/p9W4Tm
# 86179  http://news.porter.vip/2020/06/30/sopernik-lukashenko-sravnil-vliyanie-rossii-i-ssha-na-zakonnost-vyborov/?feed_id=1951&_unique_id=5efa80f023f14
#
# [86180 rows x 1 columns]

# %%
import re
import pandas as pd
import feather
from collections import Counter

# adjustable file in ftr format
save_dir = "allLinks.2020.RussianTweets.ftr"

# reads contents of save_dir.ftr
read_ftr = pd.read_feather(save_dir, columns=None, use_threads=True);

# finds 100 most common words
Counter(" ".join(read_ftr["urls"]).split()).most_common(100)
# Out:
# [('https://www.ukrinform.ua/rubric-world/3020481-medvedcuk-posirue-v-ukraini-rosijski-fejki-pro-covid19-derzdep-ssa.html',
#   422),
#  ('https://forpost.media/novosti/rozvinchano-golovni-fejki-pro-poroshenka.html',
#   212),
#  ('https://zen.yandex.ru/media/id/5eaa9fdb3c46570d62e7e327/vliianie-koronavirusa-na-fondovyi-rynok-analiz-ot-19052020-5ec26587c419064bb24de877',
#   202),
#  ('http://censor.net.ua/ua/n3193896', 201),
#  ('https://regnum.ru/news/2879660', 188),
#  ('https://t.me/MAYDNR/24440', 179),
#  ('https://bit.ly/2UzU8Bd', 159),
#  ('http://www.kim.gov.rs/v3847.php', 136),
#  ('https://newsua.one/news/medvedchuk-poshiryue-v-ukraini-rosiiski-feiki-pro-covid-19-derzhdep-ssha.html',
#   115),
#  ('https://vz.ru/news/2020/4/22/1035735.html?fbclid=IwAR32RCTz5aDNCLn3OqPYWKFRnEeydteNz4HfJQ24ISFV-5S8QtsdYG5qmnc',
#   91),
#  ('https://navalny.com/p/6336/', 90),
#  ('https://espreso.tv/news/2020/03/16/preparativ_dlya_profilaktyky_koronavirusu_poky_ne_isnuye_suprun_sprostuvala_feyky_vid_lyashka_ta_11',
#   79),
#  ('https://www.kommersant.ru/doc/4391542', 75),
#  ('https://bit.ly/2z1AplC', 68),
#  ('https://www.gazeta.ru/social/news/2020/03/25/n_14207359.shtml', 67),
#  ('https://www.rosbalt.ru/moscow/2020/05/09/1842544.html', 67),
#  ('https://m.youtube.com/channel/UCFN-r22MFS3unmBcl5qJFVA', 66),
#  ('https://oleg-leusenko.livejournal.com/12978799.html', 63),
#  ('https://twitter.com/666_mancer/status/1258112389620383749', 62),
#  ('https://twitter.com/Search_Veritas/status/1233773290583404544', 61),
#  ('https://navalny.com/p/6335/', 59),
#  ('https://www.ntv.ru/novosti/2313641/', 58),
#  ('https://youtu.be/Ha07oPvcBUc', 58),
#  ('http://censor.net.ua/ua/n3196412', 49),
#  ('https://youtu.be/yWack9L0xpg', 48),
#  ('https://youtu.be/i_U0_pVY7wU', 47),
#  ('https://24tv.ua/medvedchuk_poshiryuye_v_ukrayini_rosiyski_feyki_pro_covid_19__derzhdep_ssha_n1339464',
#   47),
#  ('https://youtu.be/mrLGO-qgLhU', 45),
#  ('https://youtu.be/cyYo2QuW8dc', 44),
#  ('https://tjournal.ru/animals/161570', 43),
#  ('https://iz.ru/1021112/2020-06-08/v-kremle-obiasnili-otsutstvie-na-saite-popravki-o-sroke-prezidenta',
#   43),
#  ('https://fakeoff.org/backstage/razumkov-prinyal-predlozhenie-akhmetova-i-sozdaet-svoyu-partiyu?utm_referrer=https%3A%2F%2Fzen.yandex.com#.XvW6ojByraQ.twitter',
#   41),
#  ('https://kungurov.livejournal.com/114057.html?utm_source=twsharing&utm_medium=social',
#   40),
#  ('https://espreso.tv/news/2020/03/23/knyazhyckyy_ta_synyutka_vymagayut_vid_sbu_ta_dbr_rozsliduvaty_feyky_buzhanskogo',
#   39),
#  ('https://www.vesti.ru/doc.html?id=3249221', 38),
#  ('https://prm.ua/knyazhitskiy-ta-sinyutka-vimagayut-vid-sbu-ta-dbr-rozsliduvati-feyki-buzhanskogo/',
#   38),
#  ('https://bbc.in/30bJwvh', 38),
#  ('https://colonelcassad.livejournal.com/5884933.html', 37),
#  ('https://www.youtube.com/watch?v=L0P3fQYNBIo', 36),
#  ('https://polynkov.livejournal.com/2224504.html', 36),
#  ('http://LIXL.RU', 35),
#  ('https://youtu.be/4EgJII8a8fk', 34),
#  ('https://youtu.be/SEgKROHYNk0', 34),
#  ('https://youtu.be/1nISzznP1cE', 34),
#  ('https://www.5.ua/suspilstvo/u-dshv-vkazaly-na-feiky-v-informatsii-rosii-pro-zatrymannia-ukrainskoho-viiskovoho-216419.html',
#   34),
#  ('https://www.facebook.com/1534949960138453/posts/2314859005480874/?vh=e&d=n',
#   33),
#  ('https://potencialex.live', 33),
#  ('https://sprotyv.info/obshchestvo/prizyv-poseshhat-hramy-v-karantin-diversiya-rpc-protiv-ukrainy-dokument?amp',
#   33),
#  ('http://apsuanews.com/2020/03/20/%d0%b3%d0%b5%d0%bd%d0%bf%d1%80%d0%be%d0%ba%d1%83%d1%80%d0%b0%d1%82%d1%83%d1%80%d0%b0-%d0%b0%d0%b1%d1%85%d0%b0%d0%b7%d0%b8%d0%b8-%d0%bf%d1%80%d0%be%d0%ba%d0%be%d0%bc%d0%bc%d0%b5%d0%bd%d1%82%d0%b8%d1%80/',
#   32),
#  ('http://www.ntv.ru/novosti/2313641/', 32),
#  ('https://sustafasti.ru/instrukcijaКак', 32),
#  ('https://youtu.be/jaEAVQyYKUs', 31),
#  ('https://varlamov.ru/3890600.html', 30),
#  ('https://uc.od.ua/columns/1533/1227391', 30),
#  ('https://youtu.be/iA1oM5XrFqs', 29),
#  ('https://youtu.be/OHXVVafb-lk', 29),
#  ('https://twitter.com/Mortis_Banned/status/1270297392827506689', 29),
#  ('https://tass.ru/obschestvo/8057217', 28),
#  ('https://zen.yandex.ru/media/id/5e41628b6ffb5072de6158f2/avasileva-i-trevva-rasprostraniaiut-feiki-o-glavvrache-bolnicy-v-volgogradskoi-oblasti-5e8f191b78fc0a040317b158',
#   28),
#  ('http://dlvr.it/RXB0xV', 28),
#  ('https://twitter.com/old_akela/status/1238119676732940288', 27),
#  ('https://aleks070565.livejournal.com/7028137.html', 27),
#  ('https://www.golos-ameriki.ru/a/russia-state-media-use-the-medical-convoy-to-italy-for-anti-western-propaganda/5346046.html',
#   27),
#  ('https://youtu.be/MlDNS0Tqkn8', 27),
#  ('https://www.patreon.com/posts/vliianie-37519710?utm_medium=social&utm_source=twitter&utm_campaign=postshare',
#   27),
#  ('https://youtu.be/haXvxJvjjsA', 27),
#  ('http://pionerprodukt.by/pionerprodukt-news/antibiotiki-v-moloke-sluxi-i-realnost.html',
#   26),
#  ('https://youtu.be/SxAgGrDORGA', 26),
#  ('http://dlvr.it/RSZB94', 26),
#  ('https://ktonanovenkogo.ru/voprosy-i-otvety/greta-tunberg-kto-ehto-takaya-diagnoz-chem-bolna.html',
#   26),
#  ('https://www.washingtonpost.com/world/europe/russia-libya-war-putin/2020/06/05/c3956bf4-a109-11ea-be06-af5514ee0385_story.html',
#   26),
#  ('http://youtu.be/-G8stiYojBQ', 25),
#  ('https://svpressa.ru/health/news/233329/?2tvb', 25),
#  ('https://bbc.in/2yGE5ZV', 25),
#  ('https://ukrmir.info/ocherednoe-nagloe-moshennichestvo-baby-yuli/', 25),
#  ('https://www.fontanka.ru/2020/06/28/69337951/?ref=t', 25),
#  ('http://trassae95.com/all/news/2020/03/31/odesskie-vrachi-zapisali-videoobracshenie-k-prezidentu-o-vranje-chinovnikov-i-katastrofe-v-medicine-56771.html',
#   24),
#  ('https://bit.ly/2wH9wTi', 23),
#  ('https://youtu.be/isQx0oDNDL8', 22),
#  ('https://qlop.ru/rynki/', 22),
#  ('https://twitter.com/NashaRada5/status/1241311489300070401?s=19', 22),
#  ('https://newsua.one/news/feiki-pro-koronavirus-poshiryuvalis-na-zamovlennya-rosii-sbu.html',
#   22),
#  ('https://www.youtube.com/watch?v=Kl6WcWiri9c', 22),
#  ('https://varlamov.ru/3944781.html', 22),
#  ('https://www.ukrinform.ua/rubric-society/2902875-fejki-pro-koronavirus-sbu-vikrila-38-dezinformatoriv-deaki-z-nih-pracuvali-na-fsb.html',
#   21),
#  ('https://youtu.be/BkJtvY5JVDs', 21),
#  ('http://go.tass.ru/3LsD', 21),
#  ('http://go.tass.ru/Hk8p', 21),
#  ('https://tass.ru/mezhdunarodnaya-panorama/8743235', 21),
#  ('https://www.interfax.ru/russia/701825', 20),
#  ('https://time.mk/c/b9ef502018/', 20),
#  ('https://ria.ru/20200403/1569535439.html', 20),
#  ('https://youtu.be/1W2Gv5sUzJ8', 20),
#  ('http://censor.net.ua/ua/n3189026', 20),
#  ('https://zen.yandex.ru/media/yanezh/vliianie-samoizoliacii-na-pensionerov-starshe-65-let-prodoljenie-5ec2e7ad41ff1b01f5418d4c',
#   20),
#  ('https://youtu.be/O9FOhAEaOlo', 20),
#  ('https://ktonanovenkogo.ru/voprosy-i-otvety/gmo-chto-ehto-takoe-rasshifrovka.html',
#   20),
#  ('http://youtu.be/_z8bX72ogCY', 19),
#  ('https://www.currenttime.tv/a/kgb-archives-chernobyl-not-great-not-terrible/29985148.html',
#   19),
#  ('http://amp.gs/H7vI', 19)]
